# %% [markdown]
# # Settings

# %%
# from google.colab import drive
# drive.mount('/content/drive')

ROOT = "/content/drive/25-2-Machine-Learning-Onions/"
import sys
sys.path.append(ROOT)

# %%
import pickle
import pandas as pd
import numpy as np
import glob

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier

from src.train_tuning import Model

is_binary = True
model_wrapper = Model(is_binary=is_binary)

# %%
all_features = ['mean_iat', 'std_iat', 'median_iat', 'q25_iat', 'q75_iat', 'ratio_out',
       'switch_count', 'duration', 'n_packets', 'burst_count', 'burst_mean',
       'burst_std', 'burst_max', 'burst_ratio_in', 'num_in', 'num_out',
       'frac_in', 'in_first30', 'out_first30', 'mean_iat_first30',
       'std_iat_first30', 'median_iat_first30', 'q25_iat_first30',
       'q75_iat_first30', 'ratio_out_first30', 'switch_count_first30',
       'duration_first30', 'burst_count_first30', 'burst_mean_first30',
       'burst_std_first30', 'burst_max_first30', 'burst_ratio_in_first30',
       'frac_in_first30'] # fixed
model_params = {
    "logit": {
        "params": {'C': 1, 'penalty': 'l2'},
        "features": all_features,
    },
    "rf": {
        "params": {'max_depth': None, 'subsample': None, 'n_estimators': 400},
        "features": all_features,
    },
    "lgb": {
        "params": {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 1.0},
        "features": all_features,
    },
    "cat": {
        "params": {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 1.0},
        "features": all_features,
    },
    "xgb": {
        "params": {'learning_rate': 0.5, 'max_depth': 10, 'num_parallel_tree':10},
        "features": all_features,
    },
    "svm": {
        "params": {"C": 10, "gamma": 0.1, "kernel": "rbf"},
        "features": all_features,
    },
}

# %% [markdown]
# # Load Data

# %%
# Load the pickle file
print("Loading datafile...")
with open(f"./data/preprocessed/open_train_33.pkl", "rb") as f:
    train = pickle.load(f)
    X_train = pd.DataFrame(train["X"])
    X_train.columns = train["feature_names"]
    y_train = train["y_binary"]
    y_train = np.where(y_train == -1, 0, y_train)

with open(f"./data/preprocessed/open_val_33.pkl", "rb") as f:
    val = pickle.load(f)
    X_val = pd.DataFrame(val["X"])
    X_val.columns = val["feature_names"]
    y_val = val["y_binary"]
    y_val = np.where(y_val == -1, 0, y_val)

print("Loading complete.")
print("Training data size:\t", len(X_train))
print("Validation data size:\t", len(X_val))
# Out:
# Loading datafile...
# Loading complete.
# Training data size:	 20300
# Validation data size:	 4350

# %%
# feature selection
def feature_selection(X, selected_features):
  return X[selected_features]

# %% [markdown]
# # Training

# %% [markdown]
# ## Base Model

# %%
for type, value in model_params.items():
    model_wrapper.create_model(type, **value.get('params'))
    model = model_wrapper._model
    features = value.get('features')
    print(f"[{model_wrapper.code}]\nparams: {model.get_params()}, features: {len(features)}")
    model_wrapper.fit(feature_selection(X_train, features), y_train)
    print(f"Accuracy: {model_wrapper.score(feature_selection(X_val, features), y_val)}")
    model_wrapper.save_model(file_name=model_wrapper.hparams)
# Out:
# [logit]
# params: {'C': 1, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}, features: 33
# Accuracy: 0.8324137931034483
# [rf]
# params: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 400, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}, features: 33
# Accuracy: 0.9241379310344827
# [lgb]
# params: {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1, 'max_depth': 10, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 200, 'n_jobs': None, 'num_leaves': 31, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0}, features: 33
# [LightGBM] [Info] Number of positive: 13300, number of negative: 7000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003820 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5200
# [LightGBM] [Info] Number of data points in the train set: 20300, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.655172 -> initscore=0.641854
# [LightGBM] [Info] Start training from score 0.641854
# Accuracy: 0.9298850574712644
# [cat]
# params: {'learning_rate': 0.1, 'bootstrap_type': 'Bernoulli', 'subsample': 1.0, 'max_depth': 10, 'n_estimators': 200}, features: 33
# 0:	learn: 0.6157958	total: 123ms	remaining: 24.5s
# 1:	learn: 0.5522739	total: 177ms	remaining: 17.5s
# 2:	learn: 0.5028499	total: 245ms	remaining: 16.1s
# 3:	learn: 0.4642209	total: 320ms	remaining: 15.7s
# 4:	learn: 0.4229373	total: 372ms	remaining: 14.5s
# 5:	learn: 0.4007315	total: 417ms	remaining: 13.5s
# 6:	learn: 0.3795252	total: 456ms	remaining: 12.6s
# 7:	learn: 0.3648456	total: 510ms	remaining: 12.2s
# 8:	learn: 0.3523832	total: 543ms	remaining: 11.5s
# 9:	learn: 0.3407229	total: 592ms	remaining: 11.2s
# 10:	learn: 0.3279811	total: 637ms	remaining: 10.9s
# 11:	learn: 0.3186615	total: 695ms	remaining: 10.9s
# 12:	learn: 0.3116646	total: 749ms	remaining: 10.8s
# 13:	learn: 0.3032609	total: 799ms	remaining: 10.6s
# 14:	learn: 0.2971125	total: 858ms	remaining: 10.6s
# 15:	learn: 0.2894217	total: 895ms	remaining: 10.3s
# 16:	learn: 0.2844496	total: 936ms	remaining: 10.1s
# 17:	learn: 0.2794380	total: 986ms	remaining: 9.97s
# 18:	learn: 0.2738923	total: 1.02s	remaining: 9.76s
# 19:	learn: 0.2701171	total: 1.07s	remaining: 9.62s
# 20:	learn: 0.2661459	total: 1.11s	remaining: 9.44s
# 21:	learn: 0.2619760	total: 1.14s	remaining: 9.25s
# 22:	learn: 0.2586490	total: 1.19s	remaining: 9.12s
# 23:	learn: 0.2544970	total: 1.23s	remaining: 9.05s
# 24:	learn: 0.2509635	total: 1.31s	remaining: 9.2s
# 25:	learn: 0.2480371	total: 1.38s	remaining: 9.26s
# 26:	learn: 0.2446088	total: 1.43s	remaining: 9.13s
# 27:	learn: 0.2418319	total: 1.46s	remaining: 8.97s
# 28:	learn: 0.2389788	total: 1.52s	remaining: 8.95s
# 29:	learn: 0.2363175	total: 1.57s	remaining: 8.92s
# 30:	learn: 0.2340159	total: 1.62s	remaining: 8.81s
# 31:	learn: 0.2321021	total: 1.66s	remaining: 8.71s
# 32:	learn: 0.2294527	total: 1.71s	remaining: 8.64s
# 33:	learn: 0.2272835	total: 1.75s	remaining: 8.57s
# 34:	learn: 0.2250300	total: 1.79s	remaining: 8.46s
# 35:	learn: 0.2228263	total: 1.85s	remaining: 8.42s
# 36:	learn: 0.2205606	total: 1.89s	remaining: 8.33s
# 37:	learn: 0.2180515	total: 1.94s	remaining: 8.25s
# 38:	learn: 0.2165351	total: 1.99s	remaining: 8.19s
# 39:	learn: 0.2142765	total: 2.03s	remaining: 8.14s
# 40:	learn: 0.2122279	total: 2.08s	remaining: 8.09s
# 41:	learn: 0.2102396	total: 2.14s	remaining: 8.07s
# 42:	learn: 0.2081148	total: 2.19s	remaining: 8s
# 43:	learn: 0.2068055	total: 2.24s	remaining: 7.94s
# 44:	learn: 0.2048112	total: 2.29s	remaining: 7.88s
# 45:	learn: 0.2036664	total: 2.32s	remaining: 7.76s
# 46:	learn: 0.2020753	total: 2.35s	remaining: 7.65s
# 47:	learn: 0.2005502	total: 2.39s	remaining: 7.57s
# 48:	learn: 0.1992900	total: 2.45s	remaining: 7.54s
# 49:	learn: 0.1979849	total: 2.5s	remaining: 7.51s
# 50:	learn: 0.1966091	total: 2.55s	remaining: 7.45s
# 51:	learn: 0.1957822	total: 2.6s	remaining: 7.39s
# 52:	learn: 0.1947939	total: 2.63s	remaining: 7.3s
# 53:	learn: 0.1928845	total: 2.68s	remaining: 7.24s
# 54:	learn: 0.1922290	total: 2.72s	remaining: 7.17s
# 55:	learn: 0.1908152	total: 2.76s	remaining: 7.1s
# 56:	learn: 0.1891457	total: 2.81s	remaining: 7.05s
# 57:	learn: 0.1876320	total: 2.86s	remaining: 6.99s
# 58:	learn: 0.1867254	total: 2.92s	remaining: 6.97s
# 59:	learn: 0.1854707	total: 2.98s	remaining: 6.94s
# 60:	learn: 0.1837168	total: 3.01s	remaining: 6.87s
# 61:	learn: 0.1824026	total: 3.06s	remaining: 6.82s
# 62:	learn: 0.1812964	total: 3.11s	remaining: 6.77s
# 63:	learn: 0.1801550	total: 3.15s	remaining: 6.7s
# 64:	learn: 0.1787651	total: 3.2s	remaining: 6.65s
# 65:	learn: 0.1776574	total: 3.24s	remaining: 6.58s
# 66:	learn: 0.1754698	total: 3.28s	remaining: 6.51s
# 67:	learn: 0.1743258	total: 3.32s	remaining: 6.45s
# 68:	learn: 0.1729659	total: 3.38s	remaining: 6.42s
# 69:	learn: 0.1719625	total: 3.43s	remaining: 6.36s
# 70:	learn: 0.1713656	total: 3.48s	remaining: 6.31s
# 71:	learn: 0.1699826	total: 3.52s	remaining: 6.26s
# 72:	learn: 0.1695025	total: 3.57s	remaining: 6.21s
# 73:	learn: 0.1680718	total: 3.61s	remaining: 6.15s
# 74:	learn: 0.1672122	total: 3.66s	remaining: 6.11s
# 75:	learn: 0.1659905	total: 3.7s	remaining: 6.04s
# 76:	learn: 0.1647987	total: 3.74s	remaining: 5.97s
# 77:	learn: 0.1640933	total: 3.78s	remaining: 5.91s
# 78:	learn: 0.1632749	total: 3.83s	remaining: 5.86s
# 79:	learn: 0.1622076	total: 3.88s	remaining: 5.81s
# 80:	learn: 0.1605428	total: 3.93s	remaining: 5.78s
# 81:	learn: 0.1587788	total: 3.99s	remaining: 5.74s
# 82:	learn: 0.1580343	total: 4.09s	remaining: 5.76s
# 83:	learn: 0.1573512	total: 4.14s	remaining: 5.72s
# 84:	learn: 0.1565568	total: 4.18s	remaining: 5.66s
# 85:	learn: 0.1554969	total: 4.22s	remaining: 5.6s
# 86:	learn: 0.1545376	total: 4.27s	remaining: 5.54s
# 87:	learn: 0.1528906	total: 4.33s	remaining: 5.51s
# 88:	learn: 0.1518384	total: 4.38s	remaining: 5.46s
# 89:	learn: 0.1510182	total: 4.42s	remaining: 5.4s
# 90:	learn: 0.1496173	total: 4.49s	remaining: 5.38s
# 91:	learn: 0.1485770	total: 4.54s	remaining: 5.33s
# 92:	learn: 0.1475714	total: 4.58s	remaining: 5.27s
# 93:	learn: 0.1466986	total: 4.63s	remaining: 5.22s
# 94:	learn: 0.1458379	total: 4.66s	remaining: 5.16s
# 95:	learn: 0.1449287	total: 4.7s	remaining: 5.09s
# 96:	learn: 0.1443320	total: 4.75s	remaining: 5.04s
# 97:	learn: 0.1429981	total: 4.79s	remaining: 4.99s
# 98:	learn: 0.1424551	total: 4.84s	remaining: 4.94s
# 99:	learn: 0.1416753	total: 4.9s	remaining: 4.9s
# 100:	learn: 0.1409514	total: 4.94s	remaining: 4.84s
# 101:	learn: 0.1398681	total: 4.99s	remaining: 4.8s
# 102:	learn: 0.1390577	total: 5.04s	remaining: 4.75s
# 103:	learn: 0.1381952	total: 5.08s	remaining: 4.69s
# 104:	learn: 0.1372920	total: 5.13s	remaining: 4.64s
# 105:	learn: 0.1363780	total: 5.17s	remaining: 4.59s
# 106:	learn: 0.1351430	total: 5.21s	remaining: 4.53s
# 107:	learn: 0.1342088	total: 5.25s	remaining: 4.47s
# 108:	learn: 0.1335665	total: 5.28s	remaining: 4.41s
# 109:	learn: 0.1324758	total: 5.33s	remaining: 4.36s
# 110:	learn: 0.1317806	total: 5.37s	remaining: 4.31s
# 111:	learn: 0.1310335	total: 5.41s	remaining: 4.25s
# 112:	learn: 0.1300396	total: 5.47s	remaining: 4.21s
# 113:	learn: 0.1287592	total: 5.5s	remaining: 4.15s
# 114:	learn: 0.1280900	total: 5.54s	remaining: 4.09s
# 115:	learn: 0.1275929	total: 5.58s	remaining: 4.04s
# 116:	learn: 0.1268675	total: 5.62s	remaining: 3.99s
# 117:	learn: 0.1258170	total: 5.67s	remaining: 3.94s
# 118:	learn: 0.1247464	total: 5.72s	remaining: 3.89s
# 119:	learn: 0.1240019	total: 5.77s	remaining: 3.85s
# 120:	learn: 0.1230975	total: 5.81s	remaining: 3.79s
# 121:	learn: 0.1224685	total: 5.86s	remaining: 3.75s
# 122:	learn: 0.1214770	total: 5.92s	remaining: 3.7s
# 123:	learn: 0.1209527	total: 5.96s	remaining: 3.65s
# 124:	learn: 0.1202438	total: 6.01s	remaining: 3.61s
# 125:	learn: 0.1197013	total: 6.07s	remaining: 3.56s
# 126:	learn: 0.1188874	total: 6.12s	remaining: 3.52s
# 127:	learn: 0.1179220	total: 6.18s	remaining: 3.47s
# 128:	learn: 0.1168123	total: 6.23s	remaining: 3.43s
# 129:	learn: 0.1162415	total: 6.29s	remaining: 3.38s
# 130:	learn: 0.1157632	total: 6.34s	remaining: 3.34s
# 131:	learn: 0.1145301	total: 6.39s	remaining: 3.29s
# 132:	learn: 0.1138107	total: 6.43s	remaining: 3.24s
# 133:	learn: 0.1130897	total: 6.5s	remaining: 3.2s
# 134:	learn: 0.1121270	total: 6.55s	remaining: 3.16s
# 135:	learn: 0.1115919	total: 6.6s	remaining: 3.11s
# 136:	learn: 0.1109103	total: 6.67s	remaining: 3.07s
# 137:	learn: 0.1104642	total: 6.72s	remaining: 3.02s
# 138:	learn: 0.1092684	total: 6.77s	remaining: 2.97s
# 139:	learn: 0.1085744	total: 6.84s	remaining: 2.93s
# 140:	learn: 0.1078367	total: 6.9s	remaining: 2.89s
# 141:	learn: 0.1068369	total: 6.96s	remaining: 2.85s
# 142:	learn: 0.1064117	total: 7.02s	remaining: 2.8s
# 143:	learn: 0.1057235	total: 7.07s	remaining: 2.75s
# 144:	learn: 0.1051974	total: 7.1s	remaining: 2.69s
# 145:	learn: 0.1045003	total: 7.15s	remaining: 2.65s
# 146:	learn: 0.1039387	total: 7.2s	remaining: 2.6s
# 147:	learn: 0.1035929	total: 7.25s	remaining: 2.55s
# 148:	learn: 0.1028494	total: 7.33s	remaining: 2.51s
# 149:	learn: 0.1021465	total: 7.37s	remaining: 2.46s
# 150:	learn: 0.1018205	total: 7.42s	remaining: 2.41s
# 151:	learn: 0.1013573	total: 7.46s	remaining: 2.36s
# 152:	learn: 0.1008891	total: 7.52s	remaining: 2.31s
# 153:	learn: 0.1002717	total: 7.57s	remaining: 2.26s
# 154:	learn: 0.0995412	total: 7.62s	remaining: 2.21s
# 155:	learn: 0.0990380	total: 7.67s	remaining: 2.16s
# 156:	learn: 0.0982829	total: 7.72s	remaining: 2.11s
# 157:	learn: 0.0976373	total: 7.77s	remaining: 2.07s
# 158:	learn: 0.0971893	total: 7.82s	remaining: 2.02s
# 159:	learn: 0.0965200	total: 7.86s	remaining: 1.96s
# 160:	learn: 0.0961088	total: 7.91s	remaining: 1.92s
# 161:	learn: 0.0957957	total: 7.96s	remaining: 1.87s
# 162:	learn: 0.0951578	total: 8.01s	remaining: 1.82s
# 163:	learn: 0.0948645	total: 8.06s	remaining: 1.77s
# 164:	learn: 0.0943174	total: 8.11s	remaining: 1.72s
# 165:	learn: 0.0934357	total: 8.16s	remaining: 1.67s
# 166:	learn: 0.0929687	total: 8.22s	remaining: 1.62s
# 167:	learn: 0.0927154	total: 8.28s	remaining: 1.58s
# 168:	learn: 0.0920360	total: 8.34s	remaining: 1.53s
# 169:	learn: 0.0911783	total: 8.38s	remaining: 1.48s
# 170:	learn: 0.0907542	total: 8.43s	remaining: 1.43s
# 171:	learn: 0.0903858	total: 8.47s	remaining: 1.38s
# 172:	learn: 0.0900984	total: 8.51s	remaining: 1.33s
# 173:	learn: 0.0896962	total: 8.55s	remaining: 1.28s
# 174:	learn: 0.0892396	total: 8.6s	remaining: 1.23s
# 175:	learn: 0.0887248	total: 8.65s	remaining: 1.18s
# 176:	learn: 0.0882216	total: 8.7s	remaining: 1.13s
# 177:	learn: 0.0877709	total: 8.76s	remaining: 1.08s
# 178:	learn: 0.0873076	total: 8.8s	remaining: 1.03s
# 179:	learn: 0.0870046	total: 8.85s	remaining: 984ms
# 180:	learn: 0.0867370	total: 8.9s	remaining: 934ms
# 181:	learn: 0.0865106	total: 8.94s	remaining: 884ms
# 182:	learn: 0.0858466	total: 8.99s	remaining: 835ms
# 183:	learn: 0.0851234	total: 9.04s	remaining: 786ms
# 184:	learn: 0.0847496	total: 9.08s	remaining: 736ms
# 185:	learn: 0.0843687	total: 9.13s	remaining: 687ms
# 186:	learn: 0.0836079	total: 9.19s	remaining: 639ms
# 187:	learn: 0.0829900	total: 9.25s	remaining: 590ms
# 188:	learn: 0.0827905	total: 9.32s	remaining: 543ms
# 189:	learn: 0.0821990	total: 9.4s	remaining: 495ms
# 190:	learn: 0.0819471	total: 9.49s	remaining: 447ms
# 191:	learn: 0.0817670	total: 9.58s	remaining: 399ms
# 192:	learn: 0.0815069	total: 9.66s	remaining: 350ms
# 193:	learn: 0.0810762	total: 9.76s	remaining: 302ms
# 194:	learn: 0.0805211	total: 9.81s	remaining: 252ms
# 195:	learn: 0.0801568	total: 9.88s	remaining: 202ms
# 196:	learn: 0.0798975	total: 9.96s	remaining: 152ms
# 197:	learn: 0.0794625	total: 10s	remaining: 101ms
# 198:	learn: 0.0791048	total: 10.1s	remaining: 50.8ms
# 199:	learn: 0.0784157	total: 10.2s	remaining: 0us
# Accuracy: 0.9285057471264367
# [xgb]
# params: {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 1, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'feature_weights': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.5, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 10, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': 100, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 1, 'tree_method': 'hist', 'validate_parameters': None, 'verbosity': None}, features: 33

# %% [markdown]
# ## Stacking

# %%
type = "stacked"
base_models = glob.glob(f"./models/binary/*.pkl")
base_models

# %%
# base model
estimators = []
print("[Load base models]")
for model_pkl in base_models:
  model_wrapper.load_model(model_pkl)
  model_nm = model_pkl.split("-")[0]
  try:
    features = model_wrapper._model.feature_names_in_
  except:
    features = model_wrapper._model.feature_names_
  print(f"- {model_nm}: {len(features)} features")
  transformer = ColumnTransformer([
      ('selector', 'passthrough', features)
  ])
  pipeline = Pipeline([
    ('preprocessor', transformer),
    ('classifier', model_wrapper._model)
  ])
  estimators.append((model_nm, pipeline))

# meta model
print("\n[Load meta model]")
meta_model = LogisticRegression()
meta_model.fit(X_train, y_train)

# %%
stacked_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)
stacked_model.fit(X_train, y_train)

model_wrapper.code = type
model_wrapper.save_model(model=stacked_model, file_name="")
