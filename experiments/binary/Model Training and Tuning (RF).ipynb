# %% [markdown]
# ## Setting

# %% [markdown]
# ### Optional

# %%
# !pip install xgboost lightgbm catboost -U
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root = "/content/drive/MyDrive/3-2 기계학습/team project/"
import sys
sys.path.append(root)

# %% [markdown]
# ### Required

# %%
from open.train_tuning import Model
from open.evaluation import show_confusion_matrix, show_roc_curve, show_pr_curve, show_prediction_score

is_binary = True

# %%
model_type = "rf"
param_grid = {
    'max_depth': [None, 4, 6],
    'max_samples': [None, 1.0],
    'n_estimators': [200, 300, 400]
}
selected_features = ['mean_iat', 'std_iat', 'median_iat', 'q25_iat', 'q75_iat', 'ratio_out',
       'switch_count', 'duration', 'n_packets', 'burst_count', 'burst_mean',
       'burst_std', 'burst_max', 'burst_ratio_in', 'num_in', 'num_out',
       'frac_in', 'in_first30', 'out_first30', 'mean_iat_first30',
       'std_iat_first30', 'median_iat_first30', 'q25_iat_first30',
       'q75_iat_first30', 'ratio_out_first30', 'switch_count_first30',
       'duration_first30', 'burst_count_first30', 'burst_mean_first30',
       'burst_std_first30', 'burst_max_first30', 'burst_ratio_in_first30',
       'frac_in_first30'] # fixed

# %% [markdown]
# ## Loading Data

# %%
import pickle
import pandas as pd
import numpy as np

use_original_data = False

# Load the pickle file
print("Loading datafile...")
with open(f"{root}data/preprocess_data_33/open_train_33.pkl", "rb") as f:
    train = pickle.load(f)
    X_train = pd.DataFrame(train["X"])
    X_train.columns = train["feature_names"]
    y_train = train["y_binary"]
    y_train = np.where(y_train == -1, 0, y_train)

with open(f"{root}data/preprocess_data_33/open_val_33.pkl", "rb") as f:
    val = pickle.load(f)
    X_val = pd.DataFrame(val["X"])
    X_val.columns = val["feature_names"]
    y_val = val["y_binary"]
    y_val = np.where(y_val == -1, 0, y_val)

if use_original_data:
  X_train = train['scaler'].inverse_transform(train['X'])
  X_train = pd.DataFrame(X_train)
  X_train.columns = train['feature_names']

  X_val = val['scaler'].inverse_transform(val['X'])
  X_val = pd.DataFrame(X_val)
  X_val.columns = val['feature_names']

print("Loading complete.")
print("Training data size:\t", len(X_train))
print("Validation data size:\t", len(X_val))
# Out:
# Loading datafile...
# Loading complete.
# Training data size:	 20300
# Validation data size:	 4350

# %%
# feature selection
def feature_selection(X, selected_features):
  return X[selected_features]

X_train = feature_selection(X_train, selected_features)
X_val = feature_selection(X_val, selected_features)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Base Model Training

# %%
model = Model(is_binary=is_binary)
# change the model type and parameters accordingly
model.create_model(model_type, n_estimators = 2)
print(model.hparams)
model.fit(X_train, y_train)
# Out:
# {'n_estimators': 2, 'max_depth': 6, 'min_samples_split': 2, 'max_features': 'sqrt', 'max_samples': 1}

# %%
y_test_pred = model.predict(X_val)
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.score(X_val, y_val)
# Out:
# 0.3448275862068966

# %%
_ = model.k_fold_cv(X_train, y_train, k = 5)
# Out:
# 5-fold Cross Validation Scores:	[0.34482759 0.34482759 0.34482759 0.34482759 0.65517241]
# 5-fold Cross Validation Average Score:	0.4068965517241379

# %% [markdown]
# ### Feature Evaluation

# %%
model.get_feature_importances()
# Out:
# {'mean_iat': 0.0,
#  'std_iat': 0.0,
#  'median_iat': 0.0,
#  'q25_iat': 0.0,
#  'q75_iat': 0.0,
#  'ratio_out': 0.0,
#  'switch_count': 0.0,
#  'duration': 0.0,
#  'n_packets': 0.0,
#  'burst_count': 0.0,
#  'burst_mean': 0.0,
#  'burst_std': 0.0,
#  'burst_max': 0.0,
#  'burst_ratio_in': 0.0,
#  'num_in': 0.0,
#  'num_out': 0.0,
#  'frac_in': 0.0,
#  'in_first30': 0.0,
#  'out_first30': 0.0,
#  'mean_iat_first30': 0.0,
#  'std_iat_first30': 0.0,
#  'median_iat_first30': 0.0,
#  'q25_iat_first30': 0.0,
#  'q75_iat_first30': 0.0,
#  'ratio_out_first30': 0.0,
#  'switch_count_first30': 0.0,
#  'duration_first30': 0.0,
#  'burst_count_first30': 0.0,
#  'burst_mean_first30': 0.0,
#  'burst_std_first30': 0.0,
#  'burst_max_first30': 0.0,
#  'burst_ratio_in_first30': 0.0,
#  'frac_in_first30': 0.0}

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# define parameter search space
bst = model.grid_search(X_train, y_train, param_grid)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END max_depth=None, max_samples=None, n_estimators=200;, score=0.916 total time=  10.8s
# [CV 2/5] END max_depth=None, max_samples=None, n_estimators=200;, score=0.920 total time=  10.5s
# [CV 3/5] END max_depth=None, max_samples=None, n_estimators=200;, score=0.917 total time=  10.6s
# [CV 4/5] END max_depth=None, max_samples=None, n_estimators=200;, score=0.920 total time=  10.5s
# [CV 5/5] END max_depth=None, max_samples=None, n_estimators=200;, score=0.922 total time=  10.5s
# [CV 1/5] END max_depth=None, max_samples=None, n_estimators=300;, score=0.915 total time=  15.7s
# [CV 2/5] END max_depth=None, max_samples=None, n_estimators=300;, score=0.922 total time=  15.6s
# [CV 3/5] END max_depth=None, max_samples=None, n_estimators=300;, score=0.915 total time=  16.8s
# [CV 4/5] END max_depth=None, max_samples=None, n_estimators=300;, score=0.919 total time=  15.7s
# [CV 5/5] END max_depth=None, max_samples=None, n_estimators=300;, score=0.923 total time=  16.0s
# [CV 1/5] END max_depth=None, max_samples=None, n_estimators=400;, score=0.917 total time=  20.8s
# [CV 2/5] END max_depth=None, max_samples=None, n_estimators=400;, score=0.923 total time=  20.6s
# [CV 3/5] END max_depth=None, max_samples=None, n_estimators=400;, score=0.917 total time=  20.8s
# [CV 4/5] END max_depth=None, max_samples=None, n_estimators=400;, score=0.919 total time=  20.8s
# [CV 5/5] END max_depth=None, max_samples=None, n_estimators=400;, score=0.925 total time=  20.7s
# [CV 1/5] END max_depth=None, max_samples=1.0, n_estimators=200;, score=0.917 total time=  10.5s
# [CV 2/5] END max_depth=None, max_samples=1.0, n_estimators=200;, score=0.920 total time=  10.4s
# [CV 3/5] END max_depth=None, max_samples=1.0, n_estimators=200;, score=0.919 total time=  10.3s
# [CV 4/5] END max_depth=None, max_samples=1.0, n_estimators=200;, score=0.920 total time=  10.5s
# [CV 5/5] END max_depth=None, max_samples=1.0, n_estimators=200;, score=0.927 total time=  10.5s
# [CV 1/5] END max_depth=None, max_samples=1.0, n_estimators=300;, score=0.917 total time=  15.5s
# [CV 2/5] END max_depth=None, max_samples=1.0, n_estimators=300;, score=0.918 total time=  15.4s
# [CV 3/5] END max_depth=None, max_samples=1.0, n_estimators=300;, score=0.918 total time=  15.9s
# [CV 4/5] END max_depth=None, max_samples=1.0, n_estimators=300;, score=0.921 total time=  15.4s
# [CV 5/5] END max_depth=None, max_samples=1.0, n_estimators=300;, score=0.923 total time=  15.4s
# [CV 1/5] END max_depth=None, max_samples=1.0, n_estimators=400;, score=0.917 total time=  21.3s
# [CV 2/5] END max_depth=None, max_samples=1.0, n_estimators=400;, score=0.921 total time=  21.1s
# [CV 3/5] END max_depth=None, max_samples=1.0, n_estimators=400;, score=0.918 total time=  21.3s
# [CV 4/5] END max_depth=None, max_samples=1.0, n_estimators=400;, score=0.919 total time=  20.9s
# [CV 5/5] END max_depth=None, max_samples=1.0, n_estimators=400;, score=0.923 total time=  20.9s
# [CV 1/5] END max_depth=4, max_samples=None, n_estimators=200;, score=0.835 total time=   4.1s
# [CV 2/5] END max_depth=4, max_samples=None, n_estimators=200;, score=0.832 total time=   3.6s
# [CV 3/5] END max_depth=4, max_samples=None, n_estimators=200;, score=0.842 total time=   3.6s
# [CV 4/5] END max_depth=4, max_samples=None, n_estimators=200;, score=0.847 total time=   4.1s
# [CV 5/5] END max_depth=4, max_samples=None, n_estimators=200;, score=0.837 total time=   3.7s
# [CV 1/5] END max_depth=4, max_samples=None, n_estimators=300;, score=0.835 total time=   5.5s
# [CV 2/5] END max_depth=4, max_samples=None, n_estimators=300;, score=0.831 total time=   5.8s
# [CV 3/5] END max_depth=4, max_samples=None, n_estimators=300;, score=0.838 total time=   5.4s
# [CV 4/5] END max_depth=4, max_samples=None, n_estimators=300;, score=0.847 total time=   5.8s
# [CV 5/5] END max_depth=4, max_samples=None, n_estimators=300;, score=0.841 total time=   5.3s
# [CV 1/5] END max_depth=4, max_samples=None, n_estimators=400;, score=0.836 total time=   7.6s
# [CV 2/5] END max_depth=4, max_samples=None, n_estimators=400;, score=0.832 total time=   7.4s
# [CV 3/5] END max_depth=4, max_samples=None, n_estimators=400;, score=0.838 total time=   7.3s
# [CV 4/5] END max_depth=4, max_samples=None, n_estimators=400;, score=0.847 total time=   7.9s
# [CV 5/5] END max_depth=4, max_samples=None, n_estimators=400;, score=0.841 total time=   7.1s
# [CV 1/5] END max_depth=4, max_samples=1.0, n_estimators=200;, score=0.834 total time=   3.9s
# [CV 2/5] END max_depth=4, max_samples=1.0, n_estimators=200;, score=0.831 total time=   3.6s
# [CV 3/5] END max_depth=4, max_samples=1.0, n_estimators=200;, score=0.838 total time=   3.6s
# [CV 4/5] END max_depth=4, max_samples=1.0, n_estimators=200;, score=0.847 total time=   4.0s
# [CV 5/5] END max_depth=4, max_samples=1.0, n_estimators=200;, score=0.844 total time=   3.6s
# [CV 1/5] END max_depth=4, max_samples=1.0, n_estimators=300;, score=0.835 total time=   5.3s
# [CV 2/5] END max_depth=4, max_samples=1.0, n_estimators=300;, score=0.832 total time=   5.7s
# [CV 3/5] END max_depth=4, max_samples=1.0, n_estimators=300;, score=0.839 total time=   5.3s
# [CV 4/5] END max_depth=4, max_samples=1.0, n_estimators=300;, score=0.850 total time=   5.7s
# [CV 5/5] END max_depth=4, max_samples=1.0, n_estimators=300;, score=0.843 total time=   5.2s
# [CV 1/5] END max_depth=4, max_samples=1.0, n_estimators=400;, score=0.837 total time=   7.3s
# [CV 2/5] END max_depth=4, max_samples=1.0, n_estimators=400;, score=0.833 total time=   7.2s
# [CV 3/5] END max_depth=4, max_samples=1.0, n_estimators=400;, score=0.839 total time=   7.2s
# [CV 4/5] END max_depth=4, max_samples=1.0, n_estimators=400;, score=0.848 total time=   7.5s
# [CV 5/5] END max_depth=4, max_samples=1.0, n_estimators=400;, score=0.843 total time=   7.1s
# [CV 1/5] END max_depth=6, max_samples=None, n_estimators=200;, score=0.869 total time=   5.3s
# [CV 2/5] END max_depth=6, max_samples=None, n_estimators=200;, score=0.868 total time=   5.0s
# [CV 3/5] END max_depth=6, max_samples=None, n_estimators=200;, score=0.868 total time=   5.3s
# [CV 4/5] END max_depth=6, max_samples=None, n_estimators=200;, score=0.873 total time=   4.8s
# [CV 5/5] END max_depth=6, max_samples=None, n_estimators=200;, score=0.868 total time=   5.2s
# [CV 1/5] END max_depth=6, max_samples=None, n_estimators=300;, score=0.869 total time=   7.4s
# [CV 2/5] END max_depth=6, max_samples=None, n_estimators=300;, score=0.867 total time=   7.9s
# [CV 3/5] END max_depth=6, max_samples=None, n_estimators=300;, score=0.868 total time=   7.3s
# [CV 4/5] END max_depth=6, max_samples=None, n_estimators=300;, score=0.871 total time=   7.6s
# [CV 5/5] END max_depth=6, max_samples=None, n_estimators=300;, score=0.867 total time=   7.8s
# [CV 1/5] END max_depth=6, max_samples=None, n_estimators=400;, score=0.869 total time=  10.3s
# [CV 2/5] END max_depth=6, max_samples=None, n_estimators=400;, score=0.869 total time=  10.1s
# [CV 3/5] END max_depth=6, max_samples=None, n_estimators=400;, score=0.869 total time=  10.1s
# [CV 4/5] END max_depth=6, max_samples=None, n_estimators=400;, score=0.872 total time=  10.2s
# [CV 5/5] END max_depth=6, max_samples=None, n_estimators=400;, score=0.865 total time=  10.2s
# [CV 1/5] END max_depth=6, max_samples=1.0, n_estimators=200;, score=0.869 total time=   5.1s
# [CV 2/5] END max_depth=6, max_samples=1.0, n_estimators=200;, score=0.869 total time=   5.1s
# [CV 3/5] END max_depth=6, max_samples=1.0, n_estimators=200;, score=0.867 total time=   4.9s
# [CV 4/5] END max_depth=6, max_samples=1.0, n_estimators=200;, score=0.872 total time=   5.3s
# [CV 5/5] END max_depth=6, max_samples=1.0, n_estimators=200;, score=0.864 total time=   4.9s
# [CV 1/5] END max_depth=6, max_samples=1.0, n_estimators=300;, score=0.867 total time=   8.0s
# [CV 2/5] END max_depth=6, max_samples=1.0, n_estimators=300;, score=0.870 total time=   8.1s
# [CV 3/5] END max_depth=6, max_samples=1.0, n_estimators=300;, score=0.869 total time=   7.5s
# [CV 4/5] END max_depth=6, max_samples=1.0, n_estimators=300;, score=0.871 total time=   7.8s
# [CV 5/5] END max_depth=6, max_samples=1.0, n_estimators=300;, score=0.867 total time=   7.6s
# [CV 1/5] END max_depth=6, max_samples=1.0, n_estimators=400;, score=0.869 total time=  10.2s
# [CV 2/5] END max_depth=6, max_samples=1.0, n_estimators=400;, score=0.867 total time=  10.3s
# [CV 3/5] END max_depth=6, max_samples=1.0, n_estimators=400;, score=0.869 total time=  10.3s
# [CV 4/5] END max_depth=6, max_samples=1.0, n_estimators=400;, score=0.873 total time=  10.2s
# [CV 5/5] END max_depth=6, max_samples=1.0, n_estimators=400;, score=0.869 total time=  10.2s
# Model type:	Random Forest Classifier Model (Bagging)
# Best score:	0.920344827586207
# Best parameters:	{'max_depth': None, 'max_samples': None, 'n_estimators': 400}
# Best estimator:	RandomForestClassifier(n_estimators=400)

# %% [markdown]
# ### Evaluation

# %%
y = y_val
y_pred = bst.predict(X_val)
y_prob = bst.predict_proba(X_val)[:, 1]

# %%
show_confusion_matrix(y, y_pred, model_type)
# Out:
# 1. Confusion Matrix
#
#               precision    recall  f1-score   support
#
#  unmonitored       0.91      0.86      0.88      1500
#    monitored       0.93      0.95      0.94      2850
#
#     accuracy                           0.92      4350
#    macro avg       0.92      0.91      0.91      4350
# weighted avg       0.92      0.92      0.92      4350

# %%
show_roc_curve(y, y_prob, model_type)
# Out:
# 2. ROC Curve
#
# - ROC AUC Score: 0.9761

# %%
show_pr_curve(y, y_prob, model_type)
# Out:
# 3. PR Curve
#
# - Average Precision (AP) Score: 0.9871

# %%
show_prediction_score(y, y_prob, model_type)
# Out:
# 4. Prediction Score

# %% [markdown]
# ### Save Model

# %%
model.save_model(model=bst.best_estimator_, file_name=f"{bst.best_params_}")
